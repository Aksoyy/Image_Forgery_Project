# %%
# Out:
# 500/65536 satir tamamlandi
# 4500/65536 satir tamamlandi
# 29700/65536 satir tamamlandi
# 36900/65536 satir tamamlandi
# 39900/65536 satir tamamlandi
# 42000/65536 satir tamamlandi
# 44900/65536 satir tamamlandi
# 45900/65536 satir tamamlandi
# 46800/65536 satir tamamlandi
# 46900/65536 satir tamamlandi
# 50900/65536 satir tamamlandi
# 52500/65536 satir tamamlandi
# 54100/65536 satir tamamlandi
# 57500/65536 satir tamamlandi
# 58400/65536 satir tamamlandi
# 59000/65536 satir tamamlandi
# 60400/65536 satir tamamlandi
# 60800/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 65000/65536 satir tamamlandi
# 65300/65536 satir tamamlandi
# 6738 degerde 12 tanesi bulundu
# Dogruluk = 0.0017809439002671415

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import cv2
import numpy as np
import matplotlib.pyplot as plt

from scipy.fftpack import dct


# In[180]:


def zig_zag(input_matrix, block_size):
    z = np.empty(block_size*block_size)
    index = -1
    bound = 0
    for i in range(0, 2 * block_size -1):
        if i < block_size:
            bound = 0
        else:
            bound = i - block_size + 1
        for j in range(bound, i - bound + 1):
            index += 1
            if i % 2 == 1:
                z[index] = int(input_matrix[j, i-j])
            else:
                z[index] = int(input_matrix[i-j, j])
    return z[:16]

def euclidian(array1, array2):
    toplam = 0
    for i in range(len(array1)):
        toplam += (int(array1[i]) - int(array2[i])) ** 2
    
    return toplam ** 0.5


# In[181]:


im = cv2.imread("f1.png", 0)
#im = cv2.imread("/home/user/Downloads/028_F.png", 0)
output_image = im
blok_boyutu = 8
yukseklik = im.shape[0]
genislik = im.shape[1]
bloklar = np.zeros((yukseklik, genislik, blok_boyutu, blok_boyutu))
dct_blogu = np.zeros_like(bloklar)
#benzerlik_yakinligi = 15
#yakinlik_esigi = 5
#cevre_esigi = 3
shift_vektorleri = []
quantalama_tablosu = np.array([1, 1, 1, 2, 1, 2, 4, 2, 2, 4, 8, 4, 2, 4, 8, 16])
#quantalama_tablosu = 16
zigzag_vektorleri = np.zeros((dct_blogu.shape[0] * dct_blogu.shape[1], 18))


# In[182]:


for i in range(yukseklik - blok_boyutu + 1):
    for j in range(genislik - blok_boyutu + 1):
        bloklar[i, j] = im[i : i + blok_boyutu, j : j + blok_boyutu]
        dct_blogu[i, j] = dct( dct( bloklar[i, j], type=3, axis=0 ), type=3, axis=1)
        zigzag_vektorleri[i * genislik + j][:16] = np.floor(zig_zag(dct_blogu[i, j], blok_boyutu) / quantalama_tablosu)
        zigzag_vektorleri[i * genislik + j][16] = i 
        zigzag_vektorleri[i * genislik + j][17] = j


# In[183]:


zigzag_vektorleri = zigzag_vektorleri.tolist()
zigzag_vektorleri = np.array(sorted(zigzag_vektorleri, key = lambda zigzag_vektorleri: zigzag_vektorleri[1]))


# In[184]:


# dist = numpy.linalg.norm(a-b)
bakilacak_vektor = 15
benzerlik_esigi = 1
yakinlik_esigi = 3
b = im
# im : 256 x 256
# bloklar : 256 x 256 x 8 x 8
# dct_blogu : 256 x 256 x 8 x 8
# Zigzag vektorleri : (256*256) x 18
for i in range(zigzag_vektorleri.shape[0] - bakilacak_vektor):
    for j in range(1, bakilacak_vektor):
        dist = euclidian(zigzag_vektorleri[i][:16], zigzag_vektorleri[i + j][:16])
        if(dist < benzerlik_esigi):
            if(i % 100 == 0):
                print("{}/{} satir tamamlandi".format(i, zigzag_vektorleri.shape[0]))
            yakinlikX = zigzag_vektorleri[i][16] - zigzag_vektorleri[i + j][16]
            yakinlikY = zigzag_vektorleri[i][17] - zigzag_vektorleri[i + j][17]
            if(((yakinlikX ** 2 + yakinlikY ** 2) ** 0.5) > yakinlik_esigi):
                b[int(zigzag_vektorleri[i][16]) : int(zigzag_vektorleri[i][16]) + blok_boyutu, 
                  int(zigzag_vektorleri[i][17]) : int(zigzag_vektorleri[i][17]) + blok_boyutu] = 255
                b[int(zigzag_vektorleri[i - j][16]) : int(zigzag_vektorleri[i - j][16]) + blok_boyutu, 
                  int(zigzag_vektorleri[i - j][17]) : int(zigzag_vektorleri[i - j][17]) + blok_boyutu] = 255

plt.figure()
plt.imshow(b, cmap="gray")
# In[185]:


# b matrisi sıfıra setlendi
#b = np.zeros_like(im)





# In[188]:


ground_truth = cv2.imread("forged1_maske.png", 0)


# In[189]:
c = np.zeros_like(b)
eslesme = 0
toplam_deger = np.unique(ground_truth, return_counts=True)[1][1]
for i in range(ground_truth.shape[0]):
    for j in range(ground_truth.shape[1]):
        if((ground_truth[i, j] == b[i, j]) and (ground_truth[i, j] == 255)):
            eslesme += 1
            c[i, j] = 128
plt.figure()
plt.imshow(c, cmap="gray")
print("{} degerde {} tanesi bulundu".format(toplam_deger, eslesme))
print("Dogruluk = {}".format(eslesme/toplam_deger))


# In[11]:


np.unique(ground_truth, return_counts=True)[1][0]
# Out:
# 500/65536 satir tamamlandi
# 4500/65536 satir tamamlandi
# 29700/65536 satir tamamlandi
# 36900/65536 satir tamamlandi
# 39900/65536 satir tamamlandi
# 42000/65536 satir tamamlandi
# 44900/65536 satir tamamlandi
# 45900/65536 satir tamamlandi
# 46800/65536 satir tamamlandi
# 46900/65536 satir tamamlandi
# 50900/65536 satir tamamlandi
# 52500/65536 satir tamamlandi
# 54100/65536 satir tamamlandi
# 57500/65536 satir tamamlandi
# 58400/65536 satir tamamlandi
# 59000/65536 satir tamamlandi
# 60400/65536 satir tamamlandi
# 60800/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61200/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61300/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61400/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61600/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61700/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61800/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 61900/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62100/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62200/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62300/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62400/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62600/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62700/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62800/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 62900/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63100/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63200/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63300/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63400/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63600/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63700/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63800/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 63900/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64100/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64200/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64300/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64400/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 64600/65536 satir tamamlandi
# 65000/65536 satir tamamlandi
# 65300/65536 satir tamamlandi
# 6738 degerde 6195 tanesi bulundu
# Dogruluk = 0.9194122885129118
# 58798

# %%
#!/usr/bin/env python
# coding: utf-8

import cv2
import numpy as np
import matplotlib.pyplot as plt

from scipy.fftpack import dct

# ZİG-ZAG TASARIMI ( İLK 16 DEGER ALINIR )
def zig_zag(input_matrix, block_size):
    z = np.empty(block_size*block_size)
    index = -1
    bound = 0
    for i in range(0, 2 * block_size -1):
        if i < block_size:
            bound = 0
        else:
            bound = i - block_size + 1
        for j in range(bound, i - bound + 1):
            index += 1
            if i % 2 == 1:
                z[index] = int(input_matrix[j, i-j])
            else:
                z[index] = int(input_matrix[i-j, j])
    return z[:16]

# ÖKLİD FONKSİYONU
def euclidian(array1, array2):
    toplam = 0
    for i in range(len(array1)):
        toplam += (int(array1[i]) - int(array2[i])) ** 2 
    return toplam ** 0.5

# RESİM YOLLARI
#im = cv2.imread("f1.png", 0)
im = cv2.imread("f1_90.png", 0)
#im = cv2.imread("f2.png", 0)
#im = cv2.imread("f2_90.png", 0)

blok_boyutu = 8 # BLOK ARALIĞI
yukseklik = im.shape[0] # SATIR SAYISI
genislik = im.shape[1] # SUTUN SAYISI

bloklar = np.zeros((yukseklik, genislik, blok_boyutu, blok_boyutu))
dct_blogu = np.zeros_like(bloklar) # bloklar ile aynı boyuttadır.

#quantalama_tablosu = np.array([1, 1, 1, 2, 1, 2, 4, 2, 2, 4, 8, 4, 2, 4, 8, 16])
quantalama_tablosu = 16
zigzag_vektorleri = np.zeros((dct_blogu.shape[0] * dct_blogu.shape[1], 18))
# boyut: [256*256,(16+2)] = (65536, 18)

# floor: Dizi öğelerinin tabanını döndürür.
for i in range(yukseklik - blok_boyutu + 1):
    for j in range(genislik - blok_boyutu + 1):
        bloklar[i, j] = im[i : i + blok_boyutu, j : j + blok_boyutu]
        dct_blogu[i, j] = dct( dct( bloklar[i, j], type=3, axis=0 ), type=3, axis=1)
        zigzag_vektorleri[i * genislik + j][:16] = np.floor(zig_zag(dct_blogu[i, j], blok_boyutu) / quantalama_tablosu)
        zigzag_vektorleri[i * genislik + j][16] = i # X konum bilgisi
        zigzag_vektorleri[i * genislik + j][17] = j # Y konum bilgisi

# VEKTORLER SIRALANMAKTADIR.
zigzag_vektorleri = zigzag_vektorleri.tolist() # DİZİ LİSTEYE CEVRİLDİ
zigzag_vektorleri = np.array(sorted(zigzag_vektorleri, key = lambda zigzag_vektorleri: zigzag_vektorleri[1]))

# KUCUK RESIM BOYUTU : 256 x 256
# BLOKLARIN BOYUTU : 256 x 256 x 8 x 8
# DCT BOYUTU : 256 x 256 x 8 x 8
# ZIGZAG VEKTORLERI : (256*256) x 18

# DEGER SETLEMELERİ
bakilacak_vektor = 25
benzerlik_esigi = 20
yakinlik_esigi = 175

for i in range(zigzag_vektorleri.shape[0] - bakilacak_vektor):
    for j in range(1, bakilacak_vektor):
        dist = euclidian(zigzag_vektorleri[i][:16], zigzag_vektorleri[i + j][:16])
        if(dist < benzerlik_esigi):
            if(i % 500 == 0):
                print("{}/{} satir tamamlandi".format(i, zigzag_vektorleri.shape[0]))
            yakinlikX = zigzag_vektorleri[i][16] - zigzag_vektorleri[i + j][16]
            yakinlikY = zigzag_vektorleri[i][17] - zigzag_vektorleri[i + j][17]
            if(((yakinlikX ** 2 + yakinlikY ** 2) ** 0.5) > yakinlik_esigi):
                im[int(zigzag_vektorleri[i][16]) : int(zigzag_vektorleri[i][16]) + blok_boyutu, 
                  int(zigzag_vektorleri[i][17]) : int(zigzag_vektorleri[i][17]) + blok_boyutu] = 255
                im[int(zigzag_vektorleri[i + j][16]) : int(zigzag_vektorleri[i + j][16]) + blok_boyutu, 
                  int(zigzag_vektorleri[i + j][17]) : int(zigzag_vektorleri[i + j][17]) + blok_boyutu] = 255

plt.figure()
plt.imshow(im, cmap="gray")

ground_truth = cv2.imread("forged1_maske.png", 0)
#ground_truth = cv2.imread("forged2_maske.png", 0)

c = np.zeros_like(im)
eslesme = 0
toplam_deger = np.unique(ground_truth, return_counts=True)[1][1]
for i in range(ground_truth.shape[0]):
    for j in range(ground_truth.shape[1]):
        if((ground_truth[i, j] == im[i, j]) and (ground_truth[i, j] == 255)):
            eslesme += 1
            c[i, j] = 128
plt.figure()
plt.imshow(c, cmap="gray")
print("{} degerde {} tanesi bulundu".format(toplam_deger, eslesme))
print("Dogruluk = {}".format(eslesme/toplam_deger))
# Out:
# 1500/65536 satir tamamlandi
# 1500/65536 satir tamamlandi
# 1500/65536 satir tamamlandi
# 1500/65536 satir tamamlandi
# 1500/65536 satir tamamlandi
# 1500/65536 satir tamamlandi
# 1500/65536 satir tamamlandi
# 1500/65536 satir tamamlandi
# 1500/65536 satir tamamlandi
# 1500/65536 satir tamamlandi
# 15500/65536 satir tamamlandi
# 15500/65536 satir tamamlandi
# 16500/65536 satir tamamlandi
# 17500/65536 satir tamamlandi
# 17500/65536 satir tamamlandi
# 18500/65536 satir tamamlandi
# 26000/65536 satir tamamlandi
# 28000/65536 satir tamamlandi
# 28000/65536 satir tamamlandi
# 28000/65536 satir tamamlandi
# 33500/65536 satir tamamlandi
# 35000/65536 satir tamamlandi
# 35500/65536 satir tamamlandi
# 35500/65536 satir tamamlandi
# 35500/65536 satir tamamlandi
# 35500/65536 satir tamamlandi
# 35500/65536 satir tamamlandi
# 35500/65536 satir tamamlandi
# 35500/65536 satir tamamlandi
# 35500/65536 satir tamamlandi
# 36000/65536 satir tamamlandi
# 36000/65536 satir tamamlandi
# 36000/65536 satir tamamlandi
# 36000/65536 satir tamamlandi
# 36500/65536 satir tamamlandi
# 38000/65536 satir tamamlandi
# 38000/65536 satir tamamlandi
# 38000/65536 satir tamamlandi
# 38000/65536 satir tamamlandi
# 39000/65536 satir tamamlandi
# 39000/65536 satir tamamlandi
# 39000/65536 satir tamamlandi
# 39000/65536 satir tamamlandi
# 39000/65536 satir tamamlandi
# 39000/65536 satir tamamlandi
# 39000/65536 satir tamamlandi
# 39500/65536 satir tamamlandi
# 39500/65536 satir tamamlandi
# 39500/65536 satir tamamlandi
# 40000/65536 satir tamamlandi
# 60000/65536 satir tamamlandi
# 60000/65536 satir tamamlandi
# 60000/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 61500/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62000/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 62500/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63000/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 63500/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64000/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 64500/65536 satir tamamlandi
# 6738 degerde 5512 tanesi bulundu
# Dogruluk = 0.8180468981893737

# %%
dct_blogu.shape
# Out:
# (256, 256, 8, 8)

# %%
zigzag_vektorleri.shape
# Out:
# (65536, 18)
